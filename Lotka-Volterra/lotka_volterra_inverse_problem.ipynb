# %%
import torch
from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt
import pickle

from scipy import integrate
import time

np.random.seed(1)

# %%
alpha = 1.5
beta = 1.75
gamma = 0.5
delta = 0.75

# %%
def rhs_lotka_volterra(t, r, alpha, beta, gamma, delta):

    x, y = r
    dx_t = alpha * x - beta * x * y
    dy_t = delta * x * y - gamma * y

    return dx_t, dy_t


def get_solution(max_t, delta_t, init_val, alpha, beta, gamma, delta):
    
    times = np.linspace(0, max_t, int(max_t / delta_t) + 1)
    sol = integrate.solve_ivp(
        rhs_lotka_volterra, [0, float(max_t)], init_val, t_eval=times,
        args=(alpha, beta, gamma, delta), rtol=1e-10, atol=1e-10
    )

    return sol.y.T

# %%
def plot_solution(times, solution, colors=None, ax=None, **kwargs):

    if ax is None:
        _, ax = plt.subplots(figsize=(10, 6))

    if colors is None:
        colors = ["black", "blue"]
    
    ax.plot(times, solution[:,0], label="x", color=colors[0], **kwargs)
    ax.plot(times, solution[:, 1], label="y", color=colors[1], **kwargs)
    ax.set_xlabel("time [s]")
    ax.spines[["top", "right"]].set_visible(False)

    return ax

# %%
init_val = np.random.uniform(0, 5, 2)
max_t = 40
delta_t = 0.1

times = np.linspace(0, max_t, int(max_t / delta_t) + 1)
true_solution = get_solution(max_t, delta_t, init_val, alpha, beta, gamma, delta)

ax = plot_solution(times, true_solution)
plt.show()
plt.close()

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cuda

# %%
class MLP(torch.nn.Module):
    """
    Define an multilayer perceptron (MLP) with arbitrary layers and Tanh activation. 
    In the time-consistent physics informed neural network (tcPINN) implementation,
    the inputs of the MLP will correspond to the time and the initial state (t, 𝑦0).
    """    
    def __init__(self, layers):
        """
        Build the MLP.
        
        Input:
        ------
        layers: list
            A list that specifies the number of neurons for each layer.
            Entry i of 'list' specifies the number of neurons in layer i.
        """
        super().__init__()
        self.depth = len(layers) - 1
        self.activation = torch.nn.Tanh
        layer_list = list()
        
        for i in range(self.depth - 1):
            
            linear_layer = torch.nn.Linear(layers[i], layers[i+1])
            torch.nn.init.xavier_normal_(linear_layer.weight, gain=5/3)
            torch.nn.init.zeros_(linear_layer.bias.data)
            
            layer_list.append(
                (f"layer_{i}", linear_layer)
            )
            layer_list.append((f"activation_{i}", self.activation()))
        
        last_layer = torch.nn.Linear(layers[-2], layers[-1])
        torch.nn.init.xavier_normal_(last_layer.weight)
        torch.nn.init.zeros_(last_layer.bias.data)
        
        layer_list.append(
            (f"layer_{self.depth - 1}", last_layer)
        )
        layerDict = OrderedDict(layer_list)
        
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
    
    
    def forward(self, x):
        """
        Apply the neural network to the input 'x'. In the tcPINN implementation,
        'x' = (t, y0), where t is the time and y0 is the initial state.
        """
        return self.layers(x)

# %%
class TcPINN:
    """
    A tcPINN implementation for Lotka-Volterra.
    """
    def __init__(self, layers, T, X_pinn=None, X_semigroup=None, X_smooth=None, X_data=None, data=None):
        """
        Initialize the MLP and the training data. It is possible to use a subset of the 
        four loss functions {standard PINN loss, semigroup loss, smoothness loss, data loss} by
        only providing some of the training data.
        
        Input:
        ------
        layers: list
            A list that specifies the number of neurons for each layer of the MLP.
            Entry i of 'list' specifies the number of neurons in layer i.
        
        T: float
            The supremum of all times in the training data. When predicting the solution of
            the ODE after time T, the trajectory has to be stitched together.
        
        X_pinn: np.ndarray
            The training data for the standard PINN loss. The first column of 'X_pinn'
            corresponds to the times, the other columns correspond to the intial values.
        
        X_semigroup: np.ndarray
            The training data for the semigroup loss. The first column of 'X_semigroup'
            corresponds to the length of the first time step, the second to the length of the
            second time step, and the other columns correspond to the intial values.
        
        X_smooth: np.ndarray
            The training data for the smoothness loss. The first column of 'X_smooth'
            corresponds to the times, the other columns correspond to the intial values.
        
        X_data: np.ndarray
            The training data for the data loss. The first column of 'X_data'
            corresponds to the times, the other columns correspond to the intial values.
        
        data: np.ndarray
            The measured/true values of the ODE for the times and initial values given by
            'X_data'.
        """
        mlp = MLP(layers)
        self._init_ode_parameters(mlp)
        self.mlp = mlp.to(device)
        self.ode_dimension = layers[-1]
        
        self.optimizer = torch.optim.LBFGS(
            self.mlp.parameters(), lr=1., max_iter=50000, max_eval=50000, 
            history_size=10, tolerance_grad=1e-5, tolerance_change=np.finfo(float).eps, 
            line_search_fn="strong_wolfe"
        )
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, mode='min', min_lr=1e-4, verbose=True
        )
        self.iter = 0
        
        self.T = torch.tensor(T).float().to(device)
        self._init_training_data(X_pinn, X_semigroup, X_smooth, X_data, data)
    
    
    def _init_ode_parameters(self, mlp):

        mlp.alpha = torch.nn.Parameter(3 * torch.rand(1, requires_grad=True)[0])
        mlp.beta = torch.nn.Parameter(3 * torch.rand(1, requires_grad=True)[0])
        mlp.gamma = torch.nn.Parameter(3 * torch.rand(1, requires_grad=True)[0])
        mlp.delta = torch.nn.Parameter(3 * torch.rand(1, requires_grad=True)[0])
        self.history = {"alpha" : [], "beta" : [], "gamma" : [], "delta" : []}
    

    def _init_training_data(self, X_pinn, X_semigroup, X_smooth, X_data, data):
        
        if X_pinn is not None:
            self.t_pinn = torch.tensor(X_pinn[:, :1], requires_grad=True).float().to(device)
            self.y_pinn = torch.tensor(X_pinn[:, 1:], requires_grad=True).float().to(device)
            self.use_standard = True
        
        else:
            self.use_standard = False
        
        if X_semigroup is not None:
            self.s_semigroup = torch.tensor(X_semigroup[:, :1], requires_grad=True).float().to(device)
            self.t_semigroup = torch.tensor(X_semigroup[:, 1:2], requires_grad=True).float().to(device)
            self.y_semigroup = torch.tensor(X_semigroup[:, 2:], requires_grad=True).float().to(device)
            self.use_semigroup = True
        
        else:
            self.use_semigroup = False
        
        if X_smooth is not None:
            self.t_smooth = torch.tensor(X_smooth[:, :1], requires_grad=True).float().to(device)
            self.y_smooth = torch.tensor(X_smooth[:, 1:], requires_grad=True).float().to(device)
            self.use_smooth = True
        
        else:
            self.use_smooth = False
        
        if X_data is not None:
            if data is None:
                raise ValueError("The true/measured solution for the 'X_data' points has to be provided.")
            self.t_data = torch.tensor(X_data[:, :1], requires_grad=True).float().to(device)
            self.y_data = torch.tensor(X_data[:, 1:], requires_grad=True).float().to(device)
            self.data = torch.tensor(data, requires_grad=True).float().to(device)
            self.use_data = True
        
        else:
            self.use_data = False
    
    
    def net_y(self, t, y0):
        """
        Let N(t, y0) denote the value of the MLP at time t for initial value y0.
        Let M(t, y0) denote the value of the tcPINN at time t for initial value y0.
        
        We set M(t, y0) = y0 + t * N(t, y0) to guarantee continuity of the trajectory
        when stitching together solutions for large times.
        """
        y = y0 + t * self.mlp(torch.cat([t, y0], dim=1))
        
        return y
    
    
    def net_derivative(self, t, y0):
        """
        Pytorch automatic differentiation to compute the derivatives of the neural network
        with respect to time.
        
        Output:
        -------
        derivatives: list
            The i-th entry is the time derivative of the i-th output component of the neural network
            evaluated at all inputs (t, y0). Each input corresponds to one row in each tensor.
        """
        y = self.net_y(t, y0)
        
        # vectors for the autograd vector Jacobian product 
        # to compute the derivatives w.r.t. every output component
        vectors = [torch.zeros_like(y) for _ in range(self.ode_dimension)]
        
        for i, vec in enumerate(vectors):
            vec[:,i] = 1.
        
        derivatives = [
            torch.autograd.grad(
                y, t, 
                grad_outputs=vec,
                retain_graph=True,
                create_graph=True
            )[0]
            for vec in vectors
        ]
        
        return derivatives
    
    
    def _loss_pinn(self):
        """
        The ODE-specific standard PINN loss.
        """
        y = self.net_y(self.t_pinn, self.y_pinn)
        deriv = self.net_derivative(self.t_pinn, self.y_pinn)
        
        loss1 = torch.mean(
            (deriv[0] - self.mlp.alpha * y[:, 0:1] + self.mlp.beta * (y[:, 0:1] * y[:, 1:2])) ** 2
        )
        loss2 = torch.mean(
            (deriv[1] - self.mlp.delta * (y[:, 0:1] * y[:, 1:2]) + self.mlp.gamma * y[:, 1:2]) ** 2
        )
        loss = loss1 + loss2

        return loss
    
    
    def _loss_semigroup(self):
        """
        The general semigroup loss.
        """
        y_no_restart = self.net_y(self.s_semigroup + self.t_semigroup, self.y_semigroup)
        y_s = self.net_y(self.s_semigroup, self.y_semigroup)
        y_restart = self.net_y(self.t_semigroup, y_s)
        loss = self.ode_dimension * torch.mean((y_no_restart - y_restart) ** 2)
        
        return loss
    
    
    def _loss_smooth(self):
        """
        The general smoothness loss.
        """
        deriv_below = self.net_derivative(self.t_smooth, self.y_smooth)
        y = self.net_y(self.t_smooth, self.y_smooth)
        deriv_above = self.net_derivative(torch.zeros_like(self.t_smooth, requires_grad=True), y)
        
        loss = .0
        
        for d1, d2 in zip(deriv_below, deriv_above):
            loss += torch.mean((d1 - d2) ** 2)
        
        return loss
    
    
    def _loss_data(self):
        """
        The general data loss.
        """
        y = self.net_y(self.t_data, self.y_data)
        loss = self.ode_dimension * torch.mean((y - self.data) ** 2)

        return loss
    
    
    def loss_function(self):
        
        self.optimizer.zero_grad()
        
        loss = .0
        
        if self.use_standard:
            loss_pinn = self._loss_pinn()
            loss += loss_pinn
        
        if self.use_semigroup:
            loss_semigroup = self._loss_semigroup()
            loss += loss_semigroup
        
        if self.use_smooth:
            loss_smooth = self._loss_smooth()
            loss += loss_smooth
        
        if self.use_data:
            loss_data = self._loss_data()
            loss += loss_data
        
        loss.backward()
        self.history["alpha"].append(self.mlp.alpha.item())
        self.history["beta"].append(self.mlp.beta.item())
        self.history["gamma"].append(self.mlp.gamma.item())
        self.history["delta"].append(self.mlp.delta.item())
        self.scheduler.step(loss)
        self.iter += 1
        
        if self.iter % 100 == 0:

            info = f"iteration {self.iter}, loss: {loss.item():.4f}"
            
            if self.use_standard:
                info += f", PINN loss: {loss_pinn.item():.4f}"
            
            if self.use_semigroup:
                info += f", semigroup loss: {loss_semigroup.item():.4f}"
            
            if self.use_smooth:
                info += f", smoothness loss: {loss_smooth.item():.4f}"
            
            if self.use_data:
                info += f", data loss: {loss_data.item():4f}"
                info += f" alpha: {self.mlp.alpha.item():.5f}, beta: {self.mlp.beta.item():.5f}, gamma: {self.mlp.gamma.item():.5f}, delta: {self.mlp.delta.item():.5f} "
            
            print(info)
        
        return loss    
    
    
    def train(self):
        """
        Train the MLP parameters with the LBFGS optimizer.
        """
        self.mlp.train()
        self.optimizer.step(self.loss_function)
    
    
    def predict(self, t, y0):
        """
        Evaluate the tcPINN at times 't' for initial values 'y0'.
        Each row (!) in 't' and 'y0' is one time point and intial value, respectively.
        """
        t = torch.tensor(t).float().to(device)
        y0 = torch.tensor(y0).float().to(device)
        
        self.mlp.eval()
        prediction = self.net_y(t, y0)
        prediction = prediction.detach().cpu().numpy()
        
        return prediction
    
    
    def predict_standard(self, max_t, delta_t, y0):
        """
        Predict the solution until time 'max_t' with step size 'delta_t' for
        a single (!) initial value 'y0'.
        
        The tcPINN is not (!) applied multiple times to stitch together trajectories.
        The predicted trajectory will therefore most likely be incorrect for all times 
        t > self.T.
        """        
        times = np.linspace(0, max_t, int(max_t / delta_t) + 1)
        times = times[:, np.newaxis]
        y0s = np.repeat(y0[np.newaxis,:], len(times), axis=0)
        
        trajectory = self.predict(times, y0s)
        
        return trajectory
    
    
    def predict_tc(self, max_t, delta_t, y0):
        """
        Predict the solution until time 'max_t' with step size 'delta_t' for
        a single (!) initial value 'y0'.
        
        The tcPINN is applied multiple times to stitch together trajectories.
        """
        T = self.T.detach().cpu().numpy()
        times = np.arange(0, np.round(T + delta_t, 3), delta_t)[1:]
        times = times[:, np.newaxis]
        n_resets = int(np.ceil(max_t / self.T.detach().cpu().numpy()))
        
        trajectory = np.array([y0])
        
        for _ in range(n_resets):
            
            y0 = trajectory[-1]
            y0s = np.repeat(y0[np.newaxis,:], len(times), axis=0)
            segment =  self.predict(times, y0s)
            trajectory = np.vstack([trajectory, segment])
        
        return trajectory

# %% [markdown]
# ### Setup Training Data

# %%
def sample_triangle_2d(n_samples, side_length):
    """
    Sample 'n_samples' points from the triangle with corners 
    (0,0), ('side_length', 0) and (0, 'side_length').
    """
    r1 = np.random.uniform(0, 1, size=n_samples)
    r2 = np.random.uniform(0, 1, size=n_samples)
    
    y0 = np.sqrt(r1) * (1 - r2)
    y1 = r2 * np.sqrt(r1)
    
    y0 *= side_length
    y1 *= side_length
    points = np.stack([y0, y1], axis=0).T
    
    return points


def sample_data(t_data, y_data, alpha, beta, gamma, delta):
    
    data = np.zeros((len(y_data), 2))

    for i, (t, init_val) in enumerate(zip(t_data, y_data)):

        data[i] = get_solution(
            max_t=t[0], delta_t=t[0], init_val=init_val, 
            alpha=alpha, beta=beta, gamma=gamma, delta=delta
        )[-1]
    
    return data

# %%
layers = [3, 128, 128, 128, 2]

T = 1
max_y0 = 5

n_pinn = 10000
t_pinn = np.random.uniform(0, T, (n_pinn, 1))
y_pinn = np.random.uniform(0, max_y0 , (n_pinn, 2))
X_pinn = np.hstack([t_pinn, y_pinn])

n_semigroup = 10000
st_semigroup = sample_triangle_2d(n_semigroup, T)
y_semigroup = np.random.uniform(0, max_y0, (n_semigroup, 2))
X_semigroup = np.hstack([st_semigroup, y_semigroup])

n_smooth = 10000
t_smooth = np.random.uniform(0, T, (n_smooth, 1))
y_smooth = np.random.uniform(0, max_y0, (n_smooth, 2))
X_smooth = np.hstack([t_smooth, y_smooth])

n_data = 10000
t_data = np.random.uniform(0, T, (n_data, 1))
y_data = np.random.uniform(0, max_y0, (n_data, 2))
X_data = np.hstack([t_data, y_data])
data = sample_data(t_data, y_data, alpha, beta, gamma, delta)

# %%
model = TcPINN(layers, T, X_pinn=X_pinn, X_semigroup=X_semigroup, X_smooth=X_smooth, X_data=X_data, data=data)

# %%
# %%time
model.train()
# Out:
# iteration 100, loss: 0.8523, PINN loss: 0.1571, semigroup loss: 0.0019, smoothness loss: 0.0577, data loss: 0.635683 alpha: -0.28819, beta: 0.68406, gamma: 0.37353, delta: 0.34121
# iteration 200, loss: 0.3707, PINN loss: 0.0730, semigroup loss: 0.0014, smoothness loss: 0.0379, data loss: 0.258339 alpha: 0.61831, beta: 1.17051, gamma: 0.46539, delta: 0.59393
# iteration 300, loss: 0.2155, PINN loss: 0.0481, semigroup loss: 0.0013, smoothness loss: 0.0330, data loss: 0.133031 alpha: 1.06490, beta: 1.42202, gamma: 0.53791, delta: 0.70043
# iteration 400, loss: 0.1379, PINN loss: 0.0339, semigroup loss: 0.0013, smoothness loss: 0.0235, data loss: 0.079279 alpha: 1.24028, beta: 1.54084, gamma: 0.47892, delta: 0.68181
# iteration 500, loss: 0.0957, PINN loss: 0.0263, semigroup loss: 0.0008, smoothness loss: 0.0172, data loss: 0.051349 alpha: 1.33062, beta: 1.63267, gamma: 0.48833, delta: 0.69335
# iteration 600, loss: 0.0671, PINN loss: 0.0162, semigroup loss: 0.0008, smoothness loss: 0.0132, data loss: 0.036883 alpha: 1.36555, beta: 1.66640, gamma: 0.47771, delta: 0.70469
# iteration 700, loss: 0.0518, PINN loss: 0.0125, semigroup loss: 0.0008, smoothness loss: 0.0089, data loss: 0.029552 alpha: 1.39147, beta: 1.66722, gamma: 0.48206, delta: 0.70823
# iteration 800, loss: 0.0408, PINN loss: 0.0102, semigroup loss: 0.0006, smoothness loss: 0.0072, data loss: 0.022912 alpha: 1.41167, beta: 1.70376, gamma: 0.48639, delta: 0.72129
# iteration 900, loss: 0.0341, PINN loss: 0.0085, semigroup loss: 0.0006, smoothness loss: 0.0059, data loss: 0.018955 alpha: 1.43557, beta: 1.71514, gamma: 0.48618, delta: 0.72677
# iteration 1000, loss: 0.0285, PINN loss: 0.0068, semigroup loss: 0.0007, smoothness loss: 0.0048, data loss: 0.016209 alpha: 1.45251, beta: 1.71649, gamma: 0.48501, delta: 0.72319
# iteration 1100, loss: 0.0257, PINN loss: 0.0059, semigroup loss: 0.0006, smoothness loss: 0.0040, data loss: 0.015133 alpha: 1.45913, beta: 1.72037, gamma: 0.48593, delta: 0.72484
# iteration 1200, loss: 0.0243, PINN loss: 0.0055, semigroup loss: 0.0005, smoothness loss: 0.0037, data loss: 0.014579 alpha: 1.45752, beta: 1.72664, gamma: 0.48847, delta: 0.72990
# iteration 1300, loss: 0.0230, PINN loss: 0.0048, semigroup loss: 0.0005, smoothness loss: 0.0035, data loss: 0.014171 alpha: 1.45971, beta: 1.72635, gamma: 0.48770, delta: 0.73042
# iteration 1400, loss: 0.0208, PINN loss: 0.0043, semigroup loss: 0.0005, smoothness loss: 0.0032, data loss: 0.012806 alpha: 1.46617, beta: 1.72343, gamma: 0.49195, delta: 0.73023
# iteration 1500, loss: 0.0186, PINN loss: 0.0036, semigroup loss: 0.0005, smoothness loss: 0.0032, data loss: 0.011249 alpha: 1.47254, beta: 1.73037, gamma: 0.48845, delta: 0.73333
# iteration 1600, loss: 0.0168, PINN loss: 0.0034, semigroup loss: 0.0005, smoothness loss: 0.0029, data loss: 0.009995 alpha: 1.47650, beta: 1.74094, gamma: 0.49534, delta: 0.73687
# iteration 1700, loss: 0.0153, PINN loss: 0.0031, semigroup loss: 0.0005, smoothness loss: 0.0029, data loss: 0.008827 alpha: 1.48206, beta: 1.74172, gamma: 0.48844, delta: 0.73567
# iteration 1800, loss: 0.0138, PINN loss: 0.0028, semigroup loss: 0.0006, smoothness loss: 0.0027, data loss: 0.007774 alpha: 1.48612, beta: 1.74007, gamma: 0.48813, delta: 0.73343
# iteration 1900, loss: 0.0125, PINN loss: 0.0027, semigroup loss: 0.0005, smoothness loss: 0.0029, data loss: 0.006388 alpha: 1.49005, beta: 1.74170, gamma: 0.49285, delta: 0.73682
# iteration 2000, loss: 0.0111, PINN loss: 0.0026, semigroup loss: 0.0004, smoothness loss: 0.0028, data loss: 0.005346 alpha: 1.49122, beta: 1.74383, gamma: 0.49166, delta: 0.73983
# iteration 2100, loss: 0.0101, PINN loss: 0.0024, semigroup loss: 0.0003, smoothness loss: 0.0025, data loss: 0.004899 alpha: 1.48843, beta: 1.74368, gamma: 0.49209, delta: 0.73733
# iteration 2200, loss: 0.0091, PINN loss: 0.0021, semigroup loss: 0.0003, smoothness loss: 0.0021, data loss: 0.004647 alpha: 1.48842, beta: 1.74357, gamma: 0.49235, delta: 0.73921
# iteration 2300, loss: 0.0086, PINN loss: 0.0020, semigroup loss: 0.0003, smoothness loss: 0.0019, data loss: 0.004361 alpha: 1.49021, beta: 1.74351, gamma: 0.49426, delta: 0.74035
# iteration 2400, loss: 0.0079, PINN loss: 0.0017, semigroup loss: 0.0003, smoothness loss: 0.0017, data loss: 0.004118 alpha: 1.49629, beta: 1.74421, gamma: 0.49625, delta: 0.74227
# iteration 2500, loss: 0.0073, PINN loss: 0.0016, semigroup loss: 0.0002, smoothness loss: 0.0015, data loss: 0.003937 alpha: 1.49928, beta: 1.74672, gamma: 0.49468, delta: 0.74183
# iteration 2600, loss: 0.0068, PINN loss: 0.0014, semigroup loss: 0.0002, smoothness loss: 0.0014, data loss: 0.003701 alpha: 1.49727, beta: 1.74904, gamma: 0.49370, delta: 0.74241
# iteration 2700, loss: 0.0064, PINN loss: 0.0014, semigroup loss: 0.0002, smoothness loss: 0.0013, data loss: 0.003574 alpha: 1.49658, beta: 1.74905, gamma: 0.49478, delta: 0.74281
# iteration 2800, loss: 0.0060, PINN loss: 0.0013, semigroup loss: 0.0002, smoothness loss: 0.0012, data loss: 0.003331 alpha: 1.49829, beta: 1.74664, gamma: 0.49532, delta: 0.74334
# iteration 2900, loss: 0.0057, PINN loss: 0.0012, semigroup loss: 0.0002, smoothness loss: 0.0011, data loss: 0.003224 alpha: 1.49837, beta: 1.74715, gamma: 0.49636, delta: 0.74368
# iteration 3000, loss: 0.0055, PINN loss: 0.0011, semigroup loss: 0.0002, smoothness loss: 0.0010, data loss: 0.003082 alpha: 1.49696, beta: 1.74758, gamma: 0.49604, delta: 0.74376
# iteration 3100, loss: 0.0052, PINN loss: 0.0010, semigroup loss: 0.0002, smoothness loss: 0.0010, data loss: 0.003079 alpha: 1.49668, beta: 1.74623, gamma: 0.49561, delta: 0.74351
# iteration 3200, loss: 0.0051, PINN loss: 0.0010, semigroup loss: 0.0002, smoothness loss: 0.0009, data loss: 0.003045 alpha: 1.49647, beta: 1.74648, gamma: 0.49612, delta: 0.74354
# iteration 3300, loss: 0.0050, PINN loss: 0.0010, semigroup loss: 0.0002, smoothness loss: 0.0009, data loss: 0.002981 alpha: 1.49701, beta: 1.74824, gamma: 0.49580, delta: 0.74426
# iteration 3400, loss: 0.0049, PINN loss: 0.0010, semigroup loss: 0.0002, smoothness loss: 0.0009, data loss: 0.002901 alpha: 1.50026, beta: 1.74957, gamma: 0.49603, delta: 0.74376
# iteration 3500, loss: 0.0047, PINN loss: 0.0009, semigroup loss: 0.0002, smoothness loss: 0.0008, data loss: 0.002775 alpha: 1.50485, beta: 1.74915, gamma: 0.49592, delta: 0.74393
# iteration 3600, loss: 0.0045, PINN loss: 0.0009, semigroup loss: 0.0002, smoothness loss: 0.0008, data loss: 0.002716 alpha: 1.50418, beta: 1.75074, gamma: 0.49681, delta: 0.74473
# iteration 3700, loss: 0.0044, PINN loss: 0.0008, semigroup loss: 0.0002, smoothness loss: 0.0008, data loss: 0.002612 alpha: 1.50094, beta: 1.75358, gamma: 0.49555, delta: 0.74517
# iteration 3800, loss: 0.0042, PINN loss: 0.0008, semigroup loss: 0.0001, smoothness loss: 0.0008, data loss: 0.002523 alpha: 1.50023, beta: 1.75107, gamma: 0.49458, delta: 0.74380
# iteration 3900, loss: 0.0040, PINN loss: 0.0008, semigroup loss: 0.0001, smoothness loss: 0.0008, data loss: 0.002280 alpha: 1.49761, beta: 1.74700, gamma: 0.49549, delta: 0.74406
# iteration 4000, loss: 0.0037, PINN loss: 0.0008, semigroup loss: 0.0002, smoothness loss: 0.0007, data loss: 0.002050 alpha: 1.49583, beta: 1.74613, gamma: 0.49780, delta: 0.74543
# iteration 4100, loss: 0.0035, PINN loss: 0.0007, semigroup loss: 0.0001, smoothness loss: 0.0007, data loss: 0.001992 alpha: 1.49774, beta: 1.74824, gamma: 0.49787, delta: 0.74641
# iteration 4200, loss: 0.0033, PINN loss: 0.0006, semigroup loss: 0.0001, smoothness loss: 0.0006, data loss: 0.001923 alpha: 1.49970, beta: 1.74981, gamma: 0.49723, delta: 0.74609
# iteration 4300, loss: 0.0032, PINN loss: 0.0006, semigroup loss: 0.0001, smoothness loss: 0.0006, data loss: 0.001887 alpha: 1.50062, beta: 1.75018, gamma: 0.49712, delta: 0.74632
# iteration 4400, loss: 0.0031, PINN loss: 0.0006, semigroup loss: 0.0001, smoothness loss: 0.0006, data loss: 0.001853 alpha: 1.50131, beta: 1.74996, gamma: 0.49798, delta: 0.74660
# iteration 4500, loss: 0.0031, PINN loss: 0.0006, semigroup loss: 0.0001, smoothness loss: 0.0006, data loss: 0.001843 alpha: 1.50148, beta: 1.74987, gamma: 0.49709, delta: 0.74604
# iteration 4600, loss: 0.0030, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001825 alpha: 1.50126, beta: 1.75060, gamma: 0.49765, delta: 0.74667
# iteration 4700, loss: 0.0029, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001774 alpha: 1.50133, beta: 1.75147, gamma: 0.49755, delta: 0.74743
# iteration 4800, loss: 0.0029, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001729 alpha: 1.50158, beta: 1.75094, gamma: 0.49771, delta: 0.74625
# iteration 4900, loss: 0.0028, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001700 alpha: 1.50231, beta: 1.74988, gamma: 0.49707, delta: 0.74617
# iteration 5000, loss: 0.0028, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001674 alpha: 1.50277, beta: 1.75030, gamma: 0.49803, delta: 0.74697
# iteration 5100, loss: 0.0027, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001643 alpha: 1.50245, beta: 1.75122, gamma: 0.49830, delta: 0.74797
# iteration 5200, loss: 0.0027, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001629 alpha: 1.50235, beta: 1.75071, gamma: 0.49786, delta: 0.74691
# iteration 5300, loss: 0.0026, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001606 alpha: 1.50167, beta: 1.75015, gamma: 0.49711, delta: 0.74647
# iteration 5400, loss: 0.0026, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.001534 alpha: 1.50024, beta: 1.74997, gamma: 0.49801, delta: 0.74681
# iteration 5500, loss: 0.0025, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.001461 alpha: 1.49930, beta: 1.75021, gamma: 0.49764, delta: 0.74692
# iteration 5600, loss: 0.0024, PINN loss: 0.0005, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.001345 alpha: 1.49957, beta: 1.74978, gamma: 0.49782, delta: 0.74688
# iteration 5700, loss: 0.0022, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001214 alpha: 1.50108, beta: 1.74972, gamma: 0.49749, delta: 0.74685
# iteration 5800, loss: 0.0021, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0005, data loss: 0.001091 alpha: 1.50241, beta: 1.75116, gamma: 0.49804, delta: 0.74717
# iteration 5900, loss: 0.0020, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.001016 alpha: 1.50253, beta: 1.75201, gamma: 0.49763, delta: 0.74788
# iteration 6000, loss: 0.0018, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.000947 alpha: 1.50196, beta: 1.75121, gamma: 0.49839, delta: 0.74793
# iteration 6100, loss: 0.0017, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.000860 alpha: 1.50037, beta: 1.74943, gamma: 0.49928, delta: 0.74840
# iteration 6200, loss: 0.0016, PINN loss: 0.0004, semigroup loss: 0.0001, smoothness loss: 0.0004, data loss: 0.000806 alpha: 1.49832, beta: 1.74817, gamma: 0.49910, delta: 0.74795
# iteration 6300, loss: 0.0015, PINN loss: 0.0003, semigroup loss: 0.0001, smoothness loss: 0.0003, data loss: 0.000780 alpha: 1.49876, beta: 1.74863, gamma: 0.49880, delta: 0.74817
# iteration 6400, loss: 0.0014, PINN loss: 0.0003, semigroup loss: 0.0001, smoothness loss: 0.0003, data loss: 0.000767 alpha: 1.49927, beta: 1.74962, gamma: 0.49886, delta: 0.74813
# iteration 6500, loss: 0.0014, PINN loss: 0.0003, semigroup loss: 0.0001, smoothness loss: 0.0003, data loss: 0.000757 alpha: 1.50049, beta: 1.75018, gamma: 0.49906, delta: 0.74873
# iteration 6600, loss: 0.0014, PINN loss: 0.0003, semigroup loss: 0.0001, smoothness loss: 0.0003, data loss: 0.000746 alpha: 1.50199, beta: 1.75064, gamma: 0.49958, delta: 0.74902
# iteration 6700, loss: 0.0013, PINN loss: 0.0003, semigroup loss: 0.0001, smoothness loss: 0.0003, data loss: 0.000729 alpha: 1.50304, beta: 1.75105, gamma: 0.49936, delta: 0.74907
# iteration 6800, loss: 0.0013, PINN loss: 0.0003, semigroup loss: 0.0000, smoothness loss: 0.0003, data loss: 0.000701 alpha: 1.50304, beta: 1.75165, gamma: 0.49904, delta: 0.74896
# iteration 6900, loss: 0.0013, PINN loss: 0.0003, semigroup loss: 0.0000, smoothness loss: 0.0003, data loss: 0.000672 alpha: 1.50253, beta: 1.75202, gamma: 0.49867, delta: 0.74878
# iteration 7000, loss: 0.0012, PINN loss: 0.0003, semigroup loss: 0.0000, smoothness loss: 0.0003, data loss: 0.000649 alpha: 1.50209, beta: 1.75134, gamma: 0.49891, delta: 0.74873
# iteration 7100, loss: 0.0012, PINN loss: 0.0003, semigroup loss: 0.0000, smoothness loss: 0.0003, data loss: 0.000636 alpha: 1.50185, beta: 1.75095, gamma: 0.49945, delta: 0.74926
# iteration 7200, loss: 0.0012, PINN loss: 0.0003, semigroup loss: 0.0000, smoothness loss: 0.0003, data loss: 0.000611 alpha: 1.50125, beta: 1.75043, gamma: 0.50008, delta: 0.74968
# iteration 7300, loss: 0.0011, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000589 alpha: 1.49986, beta: 1.74986, gamma: 0.49913, delta: 0.74913
# iteration 7400, loss: 0.0011, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000562 alpha: 1.49868, beta: 1.74972, gamma: 0.49878, delta: 0.74857
# iteration 7500, loss: 0.0011, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000540 alpha: 1.49847, beta: 1.74974, gamma: 0.49896, delta: 0.74926
# iteration 7600, loss: 0.0010, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000515 alpha: 1.49920, beta: 1.74951, gamma: 0.50089, delta: 0.75037
# iteration 7700, loss: 0.0010, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000498 alpha: 1.50009, beta: 1.74914, gamma: 0.50050, delta: 0.75019
# iteration 7800, loss: 0.0009, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000478 alpha: 1.50063, beta: 1.74926, gamma: 0.50028, delta: 0.74968
# iteration 7900, loss: 0.0009, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000466 alpha: 1.49965, beta: 1.75062, gamma: 0.49977, delta: 0.75010
# iteration 8000, loss: 0.0009, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000454 alpha: 1.49969, beta: 1.75036, gamma: 0.49952, delta: 0.74948
# iteration 8100, loss: 0.0009, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000454 alpha: 1.50018, beta: 1.74958, gamma: 0.49962, delta: 0.74923
# iteration 8200, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000449 alpha: 1.50019, beta: 1.74934, gamma: 0.50000, delta: 0.74969
# iteration 8300, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000446 alpha: 1.49987, beta: 1.74976, gamma: 0.50028, delta: 0.74991
# iteration 8400, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000443 alpha: 1.49964, beta: 1.75004, gamma: 0.49975, delta: 0.74991
# iteration 8500, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000441 alpha: 1.49965, beta: 1.75013, gamma: 0.49941, delta: 0.74933
# iteration 8600, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000436 alpha: 1.50014, beta: 1.75023, gamma: 0.49920, delta: 0.74905
# iteration 8700, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000432 alpha: 1.50096, beta: 1.75064, gamma: 0.49960, delta: 0.74942
# iteration 8800, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000428 alpha: 1.50175, beta: 1.75107, gamma: 0.49978, delta: 0.74973
# iteration 8900, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000423 alpha: 1.50240, beta: 1.75128, gamma: 0.49976, delta: 0.74969
# iteration 9000, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000419 alpha: 1.50240, beta: 1.75115, gamma: 0.49925, delta: 0.74922
# iteration 9100, loss: 0.0008, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000412 alpha: 1.50168, beta: 1.75103, gamma: 0.49916, delta: 0.74912
# iteration 9200, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000409 alpha: 1.50110, beta: 1.75076, gamma: 0.49934, delta: 0.74928
# iteration 9300, loss: 0.0007, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0002, data loss: 0.000402 alpha: 1.50062, beta: 1.75001, gamma: 0.49987, delta: 0.74962
# iteration 9400, loss: 0.0007, PINN loss: 0.0002, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000395 alpha: 1.50012, beta: 1.74934, gamma: 0.50043, delta: 0.74997
# iteration 9500, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000390 alpha: 1.49937, beta: 1.74907, gamma: 0.50002, delta: 0.74966
# iteration 9600, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000387 alpha: 1.49913, beta: 1.74949, gamma: 0.49965, delta: 0.74944
# iteration 9700, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000383 alpha: 1.49942, beta: 1.74986, gamma: 0.49942, delta: 0.74939
# iteration 9800, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000381 alpha: 1.50020, beta: 1.75005, gamma: 0.49952, delta: 0.74936
# iteration 9900, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000378 alpha: 1.50085, beta: 1.75025, gamma: 0.49987, delta: 0.74967
# iteration 10000, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000376 alpha: 1.50116, beta: 1.75065, gamma: 0.49981, delta: 0.74975
# iteration 10100, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000373 alpha: 1.50144, beta: 1.75086, gamma: 0.49938, delta: 0.74937
# iteration 10200, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000369 alpha: 1.50151, beta: 1.75082, gamma: 0.49940, delta: 0.74941
# iteration 10300, loss: 0.0007, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000362 alpha: 1.50145, beta: 1.75090, gamma: 0.49936, delta: 0.74935
# iteration 10400, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000352 alpha: 1.50150, beta: 1.75097, gamma: 0.49930, delta: 0.74932
# iteration 10500, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000342 alpha: 1.50160, beta: 1.75096, gamma: 0.49950, delta: 0.74937
# iteration 10600, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000336 alpha: 1.50156, beta: 1.75087, gamma: 0.49934, delta: 0.74932
# iteration 10700, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000327 alpha: 1.50146, beta: 1.75090, gamma: 0.49930, delta: 0.74942
# iteration 10800, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000308 alpha: 1.50110, beta: 1.75082, gamma: 0.49994, delta: 0.74984
# iteration 10900, loss: 0.0006, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000293 alpha: 1.50032, beta: 1.75058, gamma: 0.49996, delta: 0.75003
# iteration 11000, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000267 alpha: 1.49952, beta: 1.74953, gamma: 0.49993, delta: 0.74960
# iteration 11100, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000257 alpha: 1.49939, beta: 1.74937, gamma: 0.50006, delta: 0.74994
# iteration 11200, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000248 alpha: 1.49965, beta: 1.74957, gamma: 0.50026, delta: 0.74992
# iteration 11300, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000239 alpha: 1.49972, beta: 1.74994, gamma: 0.49966, delta: 0.74962
# iteration 11400, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000229 alpha: 1.49989, beta: 1.75008, gamma: 0.49942, delta: 0.74926
# iteration 11500, loss: 0.0005, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000222 alpha: 1.50042, beta: 1.75003, gamma: 0.49922, delta: 0.74914
# iteration 11600, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000213 alpha: 1.50055, beta: 1.75055, gamma: 0.49953, delta: 0.74944
# iteration 11700, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000207 alpha: 1.50059, beta: 1.75097, gamma: 0.49972, delta: 0.74995
# iteration 11800, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000202 alpha: 1.50065, beta: 1.75063, gamma: 0.49980, delta: 0.74985
# iteration 11900, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000198 alpha: 1.50047, beta: 1.74985, gamma: 0.49987, delta: 0.74975
# iteration 12000, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000197 alpha: 1.50007, beta: 1.74999, gamma: 0.49995, delta: 0.74987
# iteration 12100, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000197 alpha: 1.50002, beta: 1.74995, gamma: 0.49985, delta: 0.74972
# iteration 12200, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000196 alpha: 1.49986, beta: 1.74998, gamma: 0.49980, delta: 0.74963
# iteration 12300, loss: 0.0004, PINN loss: 0.0001, semigroup loss: 0.0000, smoothness loss: 0.0001, data loss: 0.000196 alpha: 1.49973, beta: 1.74981, gamma: 0.49969, delta: 0.74954
# Epoch 12387: reducing learning rate of group 0 to 1.0000e-01.
# CPU times: user 5min 40s, sys: 5.41 s, total: 5min 45s
# Wall time: 5min 40s

# %%
with open(f"{path}/model_lotka_volterra_inverse.pkl", "wb") as handle:
    pickle.dump(model, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(f"{path}/model_lotka_volterra_inverse.pkl", "rb") as f:
    model = pickle.load(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# plot inverse problem convergence
n_iterations = len(model.history["alpha"])
alpha_true = alpha * np.ones(n_iterations)
beta_true = beta * np.ones(n_iterations)
gamma_true = gamma * np.ones(n_iterations)
delta_true = delta * np.ones(n_iterations)


plt.plot(np.arange(n_iterations), model.history["alpha"], color="green", label="alpha")
plt.plot(np.arange(n_iterations), model.history["beta"], color="blue", label="beta")
plt.plot(np.arange(n_iterations), model.history["gamma"], color="red", label='gamma')
plt.plot(np.arange(n_iterations), model.history["delta"], color="orange", label="delta")
plt.plot(np.arange(n_iterations), alpha_true, color="black", linestyle="dashed")
plt.plot(np.arange(n_iterations), beta_true, color="black", linestyle="dashed")
plt.plot(np.arange(n_iterations), gamma_true, color="black", linestyle="dashed")
plt.plot(np.arange(n_iterations), delta_true, color="black", linestyle="dashed")


plt.legend()
plt.xlabel("Epochs")

plt.show()

# %% [markdown]
# ## Predict and Plot the Solution

# %%
# Compute the solution for a given initial condition
# Note that max_t in training is 1

y0 = np.array([0.1, 1.0]) #np.random.uniform(0, max_y0 , 2)
max_t = 100
delta_t = 0.05
times = np.linspace(0, max_t, int(max_t / delta_t) + 1)

validation_standard = model.predict_standard(max_t, delta_t, y0)
validation_tc = model.predict_tc(max_t, delta_t, y0)
true_solution = get_solution(max_t, delta_t, y0, alpha, beta, gamma, delta)

# %%
ax = plot_solution(times, true_solution, ax=None)
ax = plot_solution(times, validation_tc, ax=ax, colors=["red", "orange"], linestyle="dashed")
